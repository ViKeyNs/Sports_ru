# %%
import pandas as pd
import numpy as np
from scipy import stats
import statistics as stat

# %%
data = pd.read_csv('C:/Users/MiAir/Downloads/dataset_Facebook.csv',delimiter=';')
data.fillna(data.mean(), inplace=True)

# %%
group = data.groupby('Type')
groupType = group.agg([np.mean, np.max, np.min, np.median, mode])

# %%
def mode(numbers):
    numbers = list(numbers)
    counts = {k:numbers.count(k) for k in set(numbers)}
    modes = sorted(dict(filter(lambda x: x[1] == max(counts.values()), counts.items())).keys())
    return modes

# %%
whole = data.describe().loc[['mean','max','min','50%']]
a = pd.DataFrame(np.array([mode(data[i]) for i in data.columns]),columns=['mode']).transpose()
a.columns = data.columns
a.drop('Type',axis=1)
wholewmode = whole.append(a)
wholewmode = wholewmode.drop('Type',axis=1)
# Out:
# C:\Users\MiAir\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py:6701: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
groupType
# Out:
#        Page total likes                                    Category            \
#                    mean    amax    amin  median      mode      mean amax amin
# Type
# Link      116363.181818  138895   85979  115396  [138353]  1.136364    3    1
# Photo     122354.171362  139441   81370  128032  [124940]  1.917840    3    1
# Status    132647.044444  139441  104070  135713  [139441]  2.022222    3    1
# Video     135014.857143  138895  126424  137893  [137893]  1.000000    1    1
#
#                     ...      share                      \
#        median mode  ...       mean   amax  amin median
# Type                ...
# Link        1  [1]  ...  12.909091   44.0   0.0   10.5
# Photo       2  [1]  ...  27.159776  790.0   0.0   19.0
# Status      2  [2]  ...  31.422222  123.0   1.0   28.0
# Video       1  [1]  ...  52.142857  121.0  13.0   44.0
#
#                                 Total Interactions                    \
# ...

# %%
wholewmode
# Out:
#      Category Lifetime Engaged Users  \
# mean     1.88                920.344
# max         3                  11452
# min         1                      9
# 50%         2                  625.5
# mode      [1]                  [537]
#
#      Lifetime People who have liked your Page and engaged with your post  \
# mean                                            609.986
# max                                                4376
# min                                                   9
# 50%                                                 412
# mode                                              [403]
#
#                                 Lifetime Post Consumers  \
# mean                                            798.772
# max                                               11328
# min                                                   9
# 50%                                               551.5
# mode  [182, 298, 319, 322, 335, 374, 482, 503, 513, ...
#
# ...

# %%
def order(listik):
    orderlist = sorted(list(listik),reverse=True)
    spis = [orderlist.index(i) for i in list(listik)]
    return spis

# %%
dataforbest = data.drop(['Category','Paid','Post Hour','Post Month','Post Weekday','Type'],axis=1)
dataforbest.fillna('')
bestlist = np.zeros([1,500])
for i in dataforbest.columns:
    bestlist += np.array(order(dataforbest[i]))
data.iloc[[list(bestlist[0]).index(min(bestlist[0]))]]
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 244                    8072                     4010
#
#      Lifetime Post Consumptions  \
# 244                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions
# 244      372  5172.0  790.0                6334
